# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# ### Exercise 1
#
# Functions, comments, indentations, import, operators, brackets
#
# _Python is interpreted, Python is sensitive, = is not the same as ==, use if to make decisions, variables, the dot_

# %% [markdown]
# Exercise 2

# %%
import math 
x,y = 3,4
z = math.sqrt(x**2 + y**2)
print(x,y,z)
# Out:
# 3 4 5.0

# %% [markdown]
# Exercise 3
#
# | #    |  Term   |  Description   |
# | :--- | :---    |  :---  |
# |  1  |  Function  | A function takes an input and executes the code in the function to give an output.   |
# |  2  |  Arguments  | Arguments are the input for functions.   |
# |  3  |  Comments  | Comments provide additional information or clarity for humans reading the code.   |
# |  4  |  Indentations  | Indentations allow for nested code.   |
# |  5  |  Packages  | Packages contain a list of commonly used code that are related to each other, and can all be imported together.   |
# |  6  |  .  | The dot allows one to edit attributes of an object.   |
# |  7  |  :  | The colon allows one to define functions.  |
# |  8  |  []  | The square bracket allows one to make lists.   |
# |  9  |  [[],[]]  | This allows one to make nested lists.   |
# |  10  |  {}  |  Curly brackets allow one to define dictionaries and sets.  |

# %%
5/2         #I divide the first number by the second number and return the result.

5//2        #I divide the first number by the second number and return the floor function of the result.

5%2         #I divide the first number by the second number and return the remainder of the result.
# Out:
# 1
