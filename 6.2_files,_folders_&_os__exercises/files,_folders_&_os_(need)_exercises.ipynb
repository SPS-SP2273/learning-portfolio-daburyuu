# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Task 1

# %%
import os

months = {
         'jan': '01', 'feb': '02', 'mar': '03',
         'apr': '04', 'may': '05', 'jun': '06',
         'jul': '07', 'aug': '08', 'sep': '09',
         'oct': '10', 'nov': '11', 'dec': '12'
         }


text_name_full = "oct-08_singapore.txt"
text_month = text_name_full.split("-")[0]
text_date_city = text_name_full.split("-")[1]
text_city_path = text_date_city.split("_")[1]
text_city = text_city_path.split(".")[0]


if text_month in months.keys():
    new_text_name = f"{months[text_month]}-{text_date_city}"

    
print(new_text_name)
# Out:
# 10-08_singapore.txt

# %% [markdown]
# Task 2

# %%
months = {
         'jan': '01', 'feb': '02', 'mar': '03',
         'apr': '04', 'may': '05', 'jun': '06',
         'jul': '07', 'aug': '08', 'sep': '09',
         'oct': '10', 'nov': '11', 'dec': '12'
         }


def rename_my_file(old_file_name):
    text_month = old_file_name.split("-")[0]
    text_date_city = old_file_name.split("-")[1]
    
    
    if text_month in months.keys():
        new_text_name = f"{months[text_month]}-{text_date_city}"

    return new_text_name


print(rename_my_file("oct-08-singapore.txt"))
# Out:
# 10-08

# %% [markdown]
# Task 3

# %%
months = {
         'jan': '01', 'feb': '02', 'mar': '03',
         'apr': '04', 'may': '05', 'jun': '06',
         'jul': '07', 'aug': '08', 'sep': '09',
         'oct': '10', 'nov': '11', 'dec': '12'
         }


def rename_my_file(old_file_name):
    text_month = old_file_name.split("-")[0]
    text_date_city = old_file_name.split("-")[1]

    
    if text_month in months.keys():
        new_text_name = f"{months[text_month]}-{text_date_city}"

    return new_text_name


list_of_files = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
                 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
                 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
                 'jan-01_tokyo.txt']


for file in list_of_files:
    print(file, "---->", rename_my_file(file))
# Out:
# oct-08_singapore.txt ----> 10-08_singapore.txt
# jul-10_cairo.txt ----> 07-10_cairo.txt
# may-15_dhaka.txt ----> 05-15_dhaka.txt
# may-13_cairo.txt ----> 05-13_cairo.txt
# oct-21_cairo.txt ----> 10-21_cairo.txt
# jan-10_singapore.txt ----> 01-10_singapore.txt
# jun-20_tokyo.txt ----> 06-20_tokyo.txt
# aug-06_jakarta.txt ----> 08-06_jakarta.txt
# dec-21_karachi.txt ----> 12-21_karachi.txt
# jan-01_tokyo.txt ----> 01-01_tokyo.txt

# %% [markdown]
# Task 4

# %%
import glob


task_files = glob.glob(r"C:\Users\hangq\Downloads\os-collaboration-exercise-data/*.txt", recursive = True)


for i in task_files:
    final_name = glob.os.path.split(i)[1]
    rename_my_file(final_name)
    
    

months = {
         'jan': '01', 'feb': '02', 'mar': '03',
         'apr': '04', 'may': '05', 'jun': '06',
         'jul': '07', 'aug': '08', 'sep': '09',
         'oct': '10', 'nov': '11', 'dec': '12'
         }


def rename_my_file(old_file_name):
    text_month = old_file_name.split("-")[0]
    text_date_city = old_file_name.split("-")[1]

    
    if text_month in months.keys():
        new_text_name = f"{months[text_month]}-{text_date_city}"

    return new_text_name

# %% [markdown]
# Task 5

# %%
list_cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']


# Running code twice runs into error, hence try-except used
for city_name in list_cities:
    path_for_cities = os.path.join("Cities", city_name)
    try:
        os.mkdir(path_for_cities)
        print(f"{path_for_cities} created")
    except FileExistsError:
        print(f"{path_for_cities} already exists")
# Out:
# Cities\Cairo already exists
# Cities\Dhaka already exists
# Cities\Jakarta already exists
# Cities\Karachi already exists
# Cities\Manila already exists
# Cities\Melbourne already exists
# Cities\Osaka already exists
# Cities\Shanghai already exists
# Cities\Singapore already exists
# Cities\Tokyo already exists

# %% [markdown]
# Task 6

# %%
import shutil


glob.glob("Cities/Cairo")

for i in task_files:
    text_city = i.split("_")[-1]
    path_to_cairo_folder = os.path.join("Cities", "Cairo")
    if text_city == "cairo.txt":
        shutil.move(i, path_to_cairo_folder)
        print("done")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[29], line 11
#       9     path_to_cairo_folder = os.path.join("Cities", "Cairo")
#      10 if text_city == "cairo.txt":
# ---> 11     shutil.move(i, path_to_cairo_folder)
#      12     print("done")
#
# File c:\Users\hangq\miniconda3\Lib\shutil.py:854, in move(src, dst, copy_function)
#     851     real_dst = os.path.join(dst, _basename(src))
#     853     if os.path.exists(real_dst):
# --> 854         raise Error("Destination path '%s' already exists" % real_dst)
#     855 try:
#     856     os.rename(src, real_dst)
#
# Error: Destination path 'Cities\Cairo\apr-02_cairo.txt' already exists

# %% [markdown]
# Task 7

# %%
list_cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']


for city_name in list_cities:
    path_to_city_folder = os.path.join("Cities", city_name)
    try:
        os.mkdir(path_to_city_folder)
        print(f"{path_to_city_folder} created")
    except FileExistsError:
        print(f"{path_to_city_folder} already exists")
    for i in task_files:
        text_city = i.split("_")[-1]
        if text_city == f"{city_name}.txt":
            shutil.move(i, path_to_city_folder)
# Out:
# Cities\Cairo already exists
# Cities\Dhaka already exists
# Cities\Jakarta already exists
# Cities\Karachi already exists
# Cities\Manila already exists
# Cities\Melbourne already exists
# Cities\Osaka already exists
# Cities\Shanghai already exists
# Cities\Singapore already exists
# Cities\Tokyo already exists
