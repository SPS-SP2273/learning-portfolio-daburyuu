# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Getting ready

# %% [markdown]
# **This is some code to calculate: $y=x^2$**
#
# Testing stuff
# Testing stuff
# Testing this

# %% [markdown]
# This is a [link](https://sps.nus.edu.sg/python/docs/python_basics/01_using_jupyter/1_using-jupyter_need.html) to python basics

# %% [markdown]
# ![](https://sps.nus.edu.sg/wp-content/uploads/2024/04/SPS-Logo-Official-300x300.png)

# %% [markdown]
# # 2 Getting started with Jupyter

# %% [markdown]
# ## 2.1 It is all about running cells

# %% [markdown]
# ## 2.2 A traditional start

# %% [markdown]
# # 3 All about Markdown

# %% [markdown]
# ## 3.1 Rendering Markdown cells

# %% [markdown]
# ## 3.2 Some basic syntax

# %% [markdown]
# ## 3.3 Headings

# %% [markdown]
# ## 3.4 Displaying Code

# %% [markdown]
# ## 3.5 Links

# %% [markdown]
# ## 3.6 Images

# %% [markdown]
# ## 3.7 Tables

# %% [markdown]
# ## 3.8 Lists

# %% [markdown]
# ## 3.9 Equations

# %% [markdown]
# ## Footnotes
