# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Good) Exercises</span></div>

# %% [markdown]
# #### Exercise 1

# %%
def convert_celsius(temperature_celsius, target_scale):
    if target_scale == "Kelvin":
        temperature_kelvin = temperature_celsius + 273.15
        return temperature_kelvin
    temperature_fahrenheit = temperature_celsius * 1.8 + 32
    return temperature_fahrenheit


print(convert_celsius(0, "Kelvin"))
# Out:
# 273.15

# %% [markdown]
# #### Exercise 2

# %%
def convert_fahrenheit(temperature_fahrenheit, target_scale):
    if target_scale == "Kelvin":
        temperature_kelvin = (temperature_fahrenheit - 32) * 5 / 9 + 273.15
        return temperature_kelvin
    temperature_celsius = (temperature_fahrenheit - 32) * 5 / 9
    return temperature_celsius


print(convert_fahrenheit(32, "Kelvi"))
# Out:
# 0.0

# %% [markdown]
# #### Exercise 3

# %%
def convert_celsius(temperature_celsius, target_scale):
    if target_scale == "Kelvin":
        temperature_kelvin = temperature_celsius + 273.15
        return temperature_kelvin
    temperature_fahrenheit = temperature_celsius * 1.8 + 32
    return temperature_fahrenheit


def convert_fahrenheit(temperature_fahrenheit, target_scale):
    if target_scale == "Kelvin":
        temperature_kelvin = (temperature_fahrenheit - 32) * 5 / 9 + 273.15
        return temperature_kelvin
    temperature_celsius = (temperature_fahrenheit - 32) * 5 / 9
    return temperature_celsius




def convert_temperature(temperature, source_scale, target_scale):
    if source_scale == "Celsius":
        return convert_celsius(temperature, target_scale)
    elif source_scale == "Fahrenheit":
        return convert_fahrenheit(temperature, target_scale)
    elif source_scale == "Kelvin":
        if target_scale == "Celsius":
            temperature_celsius = temperature - 273.15
            return temperature_celsius

        # Automatically takes target_scale as Fahrenheit
        temperature_fahrenheit = (temperature - 273.15) * 1.8 + 32
        return temperature_fahrenheit


print(convert_temperature(273.15, "Kelvin", "Fahrenhei"))
# Out:
# 32.0
