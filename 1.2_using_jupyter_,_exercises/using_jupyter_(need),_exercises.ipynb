# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need), Exercises</span></div>

# %% [markdown]
# ## 1 Quadratic Equations

# %% [markdown]
# ### Introduction

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Polynomialdeg2.svg/300px-Polynomialdeg2.svg.png)
#
# *(Image from the [Wikipedia page on Quadratic Equations](https://en.wikipedia.org/wiki/Quadratic_equation))*
#
# The general form of a quadratic equation is:
#
# $$ax^2 + bx + c = 0$$

# %% [markdown]
# ### Solutions

# %% [markdown]
# Provided $a \neq 0$, we can use an elementary algebraic method called [completing the square](https://en.wikipedia.org/wiki/Completing_the_square) to show that a quadratic equation has the following solution:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$

# %% [markdown]
# ### Discriminant

# %% [markdown]
# This quantity $ \Delta = b^2 - 4ac$ is called the **discriminant** of the equation and decides the nature of its solutions. The table below shows the various possibilities.
#
#
# | Discriminant    |  Roots   |
# | :--- | :--- |
# |  $ \Delta = b^2 - 4ac$ = 0  |  A single solution of $-b/(2a)$  |
# |  $ \Delta = b^2 - 4ac$ > 0  |  Two distinct solutions  |
# |  $ \Delta = b^2 - 4ac$ < 0  |  No real solutions; both are complex.  |

# %% [markdown]
# Exercise 2
#
# 1. A Git repository is a place where all the information of a project is stored.
# 2. Git keeps track of changes in the files in our repository.
# 3. A commit is when one saves their project.
# 4. A push is when one uploads their saved project into the Git repository.
# 5. A pull is when one downloads the edited project from the Git repository and updates the local project.
# 6. GitHub is an online website that contains many different repositories from different people. GitHub Desktop is a desktop application that lets one edit their projects.

# %% [markdown]
# Exercise 3
#
# $\mu = \frac{1}{n} \sum_{i=1}^{n} x_i$
#
# $\sigma = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (x_i - \mu)^2}$
#
# $r = \frac{\sum_{i=1}^{n} (x_i - \mu_X)(y_i - \mu_Y)}{\sqrt{\sum_{i=1}^{n} (x_i - \mu_X)^2 \sum_{i=1}^{n} (y_i - \mu_Y)^2}}$
